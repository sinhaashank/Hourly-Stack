# %%
import pandas as pd
import numpy as np
import os
import sys
import plotly
import plotly.graph_objs as go
    
# %load_ext autoreload
# %autoreload 1

pd.set_option("display.max_columns",201)
pd.set_option("display.max_colwidth",101)
pd.set_option("display.max_rows",500)

# %%
from arctic import Arctic, CHUNK_STORE

conn = Arctic('10.213.120.5')
conn.initialize_library('entsoe', lib_type=CHUNK_STORE)
conn.list_libraries()
lib = conn['entsoe']
# Out:
# c:\users\a0743104\appdata\local\programs\python\python38-32\lib\site-packages\arctic\_util.py:6: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# c:\users\a0743104\appdata\local\programs\python\python38-32\lib\site-packages\arctic\store\_pandas_ndarray_store.py:6: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import DataFrame, Series, Panel
# Library created, but couldn't enable sharding: no such command: 'enablesharding'. This is OK if you're not 'admin'

# %%
lib.list_symbols()
# Out:
# ['ActualTotalLoad_BE',
#  'ActualTotalLoad_DE',
#  'ActualTotalLoad_ES',
#  'ActualTotalLoad_FR',
#  'ActualTotalLoad_GB',
#  'ActualTotalLoad_IT',
#  'ActualTotalLoad_PL',
#  'AggregatedGenerationPerType_BE',
#  'AggregatedGenerationPerType_DE',
#  'AggregatedGenerationPerType_ES',
#  'AggregatedGenerationPerType_FR',
#  'AggregatedGenerationPerType_GB',
#  'AggregatedGenerationPerType_IT',
#  'AggregatedGenerationPerType_PL',
#  'CrossBorderPhysicalFlow_AT_IT',
#  'CrossBorderPhysicalFlow_BE_FR',
#  'CrossBorderPhysicalFlow_BE_GB',
#  'CrossBorderPhysicalFlow_BE_LU',
#  'CrossBorderPhysicalFlow_BE_NL',
#  'CrossBorderPhysicalFlow_CH_DE',
#  'CrossBorderPhysicalFlow_CH_FR',
#  'CrossBorderPhysicalFlow_CH_IT',
#  'CrossBorderPhysicalFlow_CZ_PL',
#  'CrossBorderPhysicalFlow_DE_CH',
#  'CrossBorderPhysicalFlow_DE_FR',
#  'CrossBorderPhysicalFlow_DE_NL',
#  'CrossBorderPhysicalFlow_DE_PL',
#  'CrossBorderPhysicalFlow_ES_FR',
#  'CrossBorderPhysicalFlow_ES_PT',
#  'CrossBorderPhysicalFlow_FR_BE',
#  'CrossBorderPhysicalFlow_FR_CH',
#  'CrossBorderPhysicalFlow_FR_DE',
#  'CrossBorderPhysicalFlow_FR_ES',
#  'CrossBorderPhysicalFlow_FR_GB',
#  'CrossBorderPhysicalFlow_FR_IT',
#  'CrossBorderPhysicalFlow_GB_BE',
#  'CrossBorderPhysicalFlow_GB_FR',
#  'CrossBorderPhysicalFlow_GR_IT',
#  'CrossBorderPhysicalFlow_IT_AT',
#  'CrossBorderPhysicalFlow_IT_CH',
#  'CrossBorderPhysicalFlow_IT_FR',
#  'CrossBorderPhysicalFlow_IT_GR',
#  'CrossBorderPhysicalFlow_IT_ME',
#  'CrossBorderPhysicalFlow_IT_MT',
#  'CrossBorderPhysicalFlow_IT_SI',
#  'CrossBorderPhysicalFlow_LT_PL',
#  'CrossBorderPhysicalFlow_LU_BE',
#  'CrossBorderPhysicalFlow_ME_IT',
#  'CrossBorderPhysicalFlow_MT_IT',
#  'CrossBorderPhysicalFlow_NL_BE',
#  'CrossBorderPhysicalFlow_NL_DE',
#  'CrossBorderPhysicalFlow_PL_CZ',
#  'CrossBorderPhysicalFlow_PL_DE',
#  'CrossBorderPhysicalFlow_PL_LT',
#  'CrossBorderPhysicalFlow_PL_SE',
#  'CrossBorderPhysicalFlow_PL_SK',
#  'CrossBorderPhysicalFlow_PL_UA',
#  'CrossBorderPhysicalFlow_PT_ES',
#  'CrossBorderPhysicalFlow_SE_PL',
#  'CrossBorderPhysicalFlow_SI_IT',
#  'CrossBorderPhysicalFlow_SK_PL',
#  'CrossBorderPhysicalFlow_UA_PL',
#  'DayAheadAggregatedGeneration_DE',
#  'DayAheadAggregatedGeneration_FR',
#  'DayAheadCommercialSchedules_BE_FR',
#  'DayAheadCommercialSchedules_CH_DE',
#  'DayAheadCommercialSchedules_CH_FR',
#  'DayAheadCommercialSchedules_DE_CH',
#  'DayAheadCommercialSchedules_DE_FR',
#  'DayAheadCommercialSchedules_DE_NL',
#  'DayAheadCommercialSchedules_DE_PL',
#  'DayAheadCommercialSchedules_ES_FR',
#  'DayAheadCommercialSchedules_FR_BE',
#  'DayAheadCommercialSchedules_FR_CH',
#  'DayAheadCommercialSchedules_FR_DE',
#  'DayAheadCommercialSchedules_FR_ES',
#  'DayAheadCommercialSchedules_FR_GB',
#  'DayAheadCommercialSchedules_FR_IT',
#  'DayAheadCommercialSchedules_GB_FR',
#  'DayAheadCommercialSchedules_IT_FR',
#  'DayAheadCommercialSchedules_NL_DE',
#  'DayAheadCommercialSchedules_PL_DE',
#  'DayAheadGenerationForecastWindSolar_DE',
#  'DayAheadGenerationForecastWindSolar_FR',
#  'DayAheadPrices_AT',
#  'DayAheadPrices_BE',
#  'DayAheadPrices_CH',
#  'DayAheadPrices_DE',
#  'DayAheadPrices_ES',
#  'DayAheadPrices_FR',
#  'DayAheadPrices_GB',
#  'DayAheadPrices_IT',
#  'DayAheadPrices_NL',
#  'DayAheadPrices_PL',
#  'DayAheadTotalLoadForecast_DE',
#  'DayAheadTotalLoadForecast_FR',
#  'InstalledGenerationCapacityAggregated_BE',
#  'InstalledGenerationCapacityAggregated_DE',
#  'InstalledGenerationCapacityAggregated_ES',
#  'InstalledGenerationCapacityAggregated_FR',
#  'InstalledGenerationCapacityAggregated_GB',
#  'InstalledGenerationCapacityAggregated_IT',
#  'InstalledGenerationCapacityAggregated_PL',
#  'ScheduledCommercialExchanges_BE_FR',
#  'ScheduledCommercialExchanges_CH_DE',
#  'ScheduledCommercialExchanges_CH_FR',
#  'ScheduledCommercialExchanges_DE_CH',
#  'ScheduledCommercialExchanges_DE_FR',
#  'ScheduledCommercialExchanges_DE_NL',
#  'ScheduledCommercialExchanges_DE_PL',
#  'ScheduledCommercialExchanges_ES_FR',
#  'ScheduledCommercialExchanges_FR_BE',
#  'ScheduledCommercialExchanges_FR_CH',
#  'ScheduledCommercialExchanges_FR_DE',
#  'ScheduledCommercialExchanges_FR_ES',
#  'ScheduledCommercialExchanges_FR_GB',
#  'ScheduledCommercialExchanges_FR_IT',
#  'ScheduledCommercialExchanges_GB_FR',
#  'ScheduledCommercialExchanges_IT_FR',
#  'ScheduledCommercialExchanges_NL_DE',
#  'ScheduledCommercialExchanges_PL_DE',
#  'UseOfTransferCapacityMonthly_DE_FR',
#  'UseOfTransferCapacityMonthly_FR_DE',
#  'UseOfTransferCapacityMonthly_FR_IT',
#  'UseOfTransferCapacityMonthly_IT_FR']

# %%
def last_day_of_month(date_value):
    return date_value.replace(day = monthrange(date_value.year, date_value.month)[1])

# %%
# function to change timezone from UTC to local time

def changing_timezone(x):
    ts = x.index.tz_localize('utc').tz_convert('Europe/Brussels')
    y = x.set_index(ts)
    return y.tz_localize(None)

# %%
# Input country

country = input("Enter the perimeter (DE/FR/BE/ES/IT/PL) : ")
# Out:
# Enter the perimeter (DE/FR/BE/ES/IT/PL) : FR

# %%
# Input a month

from datetime import datetime
from datetime import timedelta
from calendar import monthrange

# Input month and year
    
month = int(input("Enter a Month Number (1 to 12): "))
year = int(input("Enter a Year (2015 onwards): "))
    
ref_date = datetime(year=year, month=month, day=1).date()

start_date = ref_date + timedelta(days = - 1)
end_date = last_day_of_month(ref_date) + timedelta(days = 1)
# Out:
# Enter a Month Number (1 to 12): 5
# Enter a Year (2015 onwards): 2019

# %%
# Read Spot price

read = 'DayAheadPrices'
prefix = read + '_' + country 

DA_price = lib.read(prefix, chunk_range=pd.date_range(start_date, end_date))

# %%
if country == 'DE':
    interco = ['FR','CH','PL'] # NL to be added
elif country == 'FR':
    interco = ['DE','BE','CH','IT','ES'] # UK to be added
elif country == 'BE':
    interco = ['FR'] # NL and UK to be added
elif country == 'ES':
    interco = ['FR']
elif country == 'IT':
    interco = ['FR','CH','AT']
elif country == 'PL':
    interco = ['DE'] # to add CZ?

# %%
df_interco = pd.DataFrame(columns=[])
for i in interco:
    prefix = read + '_' + i 
    spot = lib.read(prefix, chunk_range=pd.date_range(start_date, end_date))
    df_interco = pd.merge(df_interco,spot ,how='outer',right_index=True, left_index=True)

df_DA_price = pd.merge(DA_price, df_interco,how='outer',right_index=True, left_index=True)

# %%
# Read demand data

read = 'ActualTotalLoad'
prefix = read + '_' + country 

demand = lib.read(prefix, chunk_range=pd.date_range(start_date, end_date))

# convert 15 min data to hourly data
demand = demand.resample('H').mean()

# %%
# Read power generation data

read = 'AggregatedGenerationPerType'
prefix = read + '_' + country 

gen = lib.read(prefix, chunk_range=pd.date_range(start_date, end_date))

# convert 15 min data to hourly data
gen = gen.resample('H').mean()

# %%
# Read cross border flows

read = 'ScheduledCommercialExchanges'

# exports
df_exports = pd.DataFrame(columns=[])
for i in interco:
    prefix = read + '_' + country + '_' + i 
    out_flows = lib.read(prefix, chunk_range=pd.date_range(start_date, end_date))
    df_exports = pd.merge(df_exports,out_flows ,how='outer',right_index=True, left_index=True)    
    
# imports
df_imports = pd.DataFrame(columns=[])
for j in interco:
    prefix = read + '_' + j + '_' + country
    in_flows = lib.read(prefix, chunk_range=pd.date_range(start_date, end_date))
    df_imports = pd.merge(df_imports,in_flows ,how='outer',right_index=True, left_index=True) 

df_flows = df_exports.subtract(df_imports.values)

# %%
# changing timezones 

df_DA_price = changing_timezone(df_DA_price)
demand = changing_timezone(demand)
gen = changing_timezone(gen)
df_flows =changing_timezone(df_flows)

# %%
# merging data to a single dataframe

var = [df_DA_price,demand,gen,df_flows]     
df_merge = pd.DataFrame(columns=[])

for df in var:
    df_merge = pd.merge(df_merge, df,how='outer',right_index=True, left_index=True)

# %%
df_merge
# Out:
#                      DayAheadPrices_FR  DayAheadPrices_DE  DayAheadPrices_BE  \
# date
# 2019-04-30 02:00:00              35.00              35.00              35.00
# 2019-04-30 03:00:00              35.24              35.24              35.24
# 2019-04-30 04:00:00              34.44              34.44              34.44
# 2019-04-30 05:00:00              36.59              37.04              36.75
# 2019-04-30 06:00:00              45.62              45.62              45.62
# ...                                ...                ...                ...
# 2019-05-31 22:00:00              43.98              43.98              43.98
# 2019-05-31 23:00:00              40.00              40.00              40.00
# 2019-06-01 00:00:00              33.63              33.63              33.63
# 2019-06-01 01:00:00              31.03              31.03              31.03
# 2019-06-01 02:00:00              28.23              28.23              28.23
#
#                      DayAheadPrices_CH  DayAheadPrices_IT  DayAheadPrices_ES  \
# date
# 2019-04-30 02:00:00              35.31              46.79              58.71
# 2019-04-30 03:00:00              34.58              47.24              58.71
# 2019-04-30 04:00:00              34.80              47.27              58.91
# 2019-04-30 05:00:00              37.12              53.89              59.47
# 2019-04-30 06:00:00              46.60              57.60              59.89
# ...                                ...                ...                ...
# 2019-05-31 22:00:00              41.95              47.66              55.98
# 2019-05-31 23:00:00              37.07              45.18              55.98
# 2019-06-01 00:00:00              36.28              59.41              59.21
# 2019-06-01 01:00:00              32.03              47.98              59.00
# 2019-06-01 02:00:00              30.69              47.70              58.22
#
#                      ActualTotalLoad_FR  ActualGenerationOutput FR Biomass  \
# date
# 2019-04-30 02:00:00             46412.0                              323.0
# 2019-04-30 03:00:00             44472.0                              323.0
# 2019-04-30 04:00:00             44137.0                              322.0
# 2019-04-30 05:00:00             46643.0                              322.0
# 2019-04-30 06:00:00             51355.0                              322.0
# ...                                 ...                                ...
# 2019-05-31 22:00:00             45394.0                              315.0
# 2019-05-31 23:00:00             46585.0                              317.0
# 2019-06-01 00:00:00             43098.0                              316.0
# 2019-06-01 01:00:00             40088.0                              313.0
# 2019-06-01 02:00:00             38179.0                              313.0
#
#                      ActualGenerationOutput FR Fossil Gas  \
# date
# 2019-04-30 02:00:00                                3651.0
# 2019-04-30 03:00:00                                3658.0
# 2019-04-30 04:00:00                                3725.0
# 2019-04-30 05:00:00                                4133.0
# 2019-04-30 06:00:00                                4203.0
# ...                                                   ...
# 2019-05-31 22:00:00                                2123.0
# 2019-05-31 23:00:00                                2155.0
# 2019-06-01 00:00:00                                1845.0
# 2019-06-01 01:00:00                                 882.0
# 2019-06-01 02:00:00                                 681.0
#
#                      ActualGenerationOutput FR Fossil Hard coal  \
# date
# 2019-04-30 02:00:00                                        17.0
# 2019-04-30 03:00:00                                        17.0
# 2019-04-30 04:00:00                                        17.0
# 2019-04-30 05:00:00                                        17.0
# 2019-04-30 06:00:00                                        17.0
# ...                                                         ...
# 2019-05-31 22:00:00                                         8.0
# 2019-05-31 23:00:00                                         8.0
# 2019-06-01 00:00:00                                         8.0
# 2019-06-01 01:00:00                              0.0
# 2019-06-01 02:00:00                              0.0
#
#                      ActualGenerationOutput FR Waste  \
# date
# 2019-04-30 02:00:00                            193.0
# 2019-04-30 03:00:00                            193.0
# 2019-04-30 04:00:00                            193.0
# 2019-04-30 05:00:00                            192.0
# 2019-04-30 06:00:00                            190.0
# ...                                              ...
# 2019-05-31 22:00:00                            176.0
# 2019-05-31 23:00:00                            178.0
# 2019-06-01 00:00:00                            185.0
# 2019-06-01 01:00:00                            187.0
# 2019-06-01 02:00:00                            187.0
#
#                      ActualGenerationOutput FR Wind Onshore  \
# date
# 2019-04-30 02:00:00                                  2428.0
# 2019-04-30 03:00:00                                  2390.0
# 2019-04-30 04:00:00                                  2384.0
# 2019-04-30 05:00:00                                  2278.0
# 2019-04-30 06:00:00                                  2124.0
# ...                                                     ...
# 2019-05-31 22:00:00                                   715.0
# 2019-05-31 23:00:00                                   774.0
# 2019-06-01 00:00:00                                   882.0
# 2019-06-01 01:00:00                                  1016.0
# 2019-06-01 02:00:00                                  1160.0
#
#                      ActualConsumption FR Biomass  \
# date
# 2019-04-30 02:00:00                           NaN
# 2019-04-30 03:00:00                           NaN
# 2019-04-30 04:00:00                           NaN
# 2019-04-30 05:00:00                           NaN
# 2019-04-30 06:00:00                           NaN
# ...                                           ...
# 2019-05-31 22:00:00                           NaN
# 2019-05-31 23:00:00                           NaN
# 2019-06-01 00:00:00                           NaN
# 2019-06-01 01:00:00                           NaN
# 2019-06-01 02:00:00                           NaN
#
#                      ActualConsumption FR Fossil Gas  \
# date
# 2019-04-30 02:00:00                              NaN
# 2019-04-30 03:00:00                              NaN
# 2019-04-30 04:00:00                              NaN
# 2019-04-30 05:00:00                              NaN
# 2019-04-30 06:00:00                              NaN
# ...                                              ...
# 2019-05-31 22:00:00                              NaN
# 2019-05-31 23:00:00                              NaN
# 2019-06-01 00:00:00                              NaN
# 2019-06-01 01:00:00                              NaN
# 2019-06-01 02:00:00                              NaN
#
#                      ActualConsumption FR Fossil Hard coal  \
# date
# 2019-04-30 02:00:00                                    NaN
# 2019-04-30 03:00:00                                    NaN
# 2019-04-30 04:00:00                                    NaN
# 2019-04-30 05:00:00                                    NaN
# 2019-04-30 06:00:00                                    NaN
# ...                                                    ...
# 2019-05-31 22:00:00                                    NaN
# 2019-05-31 23:00:00                                    NaN
# 2019-06-01 00:00:00                                    NaN
# 2019-06-01 01:00:00                                    NaN
# 2019-06-01 02:00:00                                    NaN
#
#                      ActualConsumption FR Fossil Oil  \
# date
# 2019-04-30 02:00:00                              NaN
# 2019-04-30 03:00:00                              NaN
# 2019-04-30 04:00:00                              NaN
# 2019-04-30 05:00:00                              NaN
# 2019-04-30 06:00:00                              NaN
# ...                                              ...
# 2019-05-31 22:00:00                              NaN
# 2019-05-31 23:00:00                              NaN
# 2019-06-01 00:00:00                              NaN
# 2019-06-01 01:00:00                              NaN
# 2019-06-01 02:00:00                              NaN
#
#                      ActualConsumption FR Hydro Pumped Storage  \
# date
# 2019-04-30 02:00:00                                      854.0
# 2019-04-30 03:00:00                                     1227.0
# 2019-04-30 04:00:00                                     1379.0
# 2019-04-30 05:00:00                                      726.0
# 2019-04-30 06:00:00                                        NaN
# ...                                                        ...
# 2019-05-31 22:00:00                                        NaN
# 2019-05-31 23:00:00                                        NaN
# 2019-06-01 00:00:00                                        NaN
# 2019-06-01 01:00:00                                      398.0
# 2019-06-01 02:00:00                                      779.0
#
#                      ActualConsumption FR Hydro Run-of-river and poundage  \
# date
# 2019-04-30 02:00:00                                                   NaN
# 2019-04-30 03:00:00                                                   NaN
# 2019-04-30 04:00:00                                                   NaN
# 2019-04-30 05:00:00                                                   NaN
# 2019-04-30 06:00:00                                                   NaN
# ...                                                                   ...
# 2019-05-31 22:00:00                                                   NaN
# 2019-05-31 23:00:00                                                   NaN
# 2019-06-01 00:00:00                                                   NaN
# 2019-06-01 01:00:00                                                   NaN
# 2019-06-01 02:00:00                                                   NaN
#
#                      ActualConsumption FR Hydro Water Reservoir  \
# date
# 2019-04-30 02:00:00                                         NaN
# 2019-04-30 03:00:00                                         NaN
# 2019-04-30 04:00:00                                         NaN
# 2019-04-30 05:00:00                                         NaN
# 2019-04-30 06:00:00                                         NaN
# ...                                                         ...
# 2019-05-31 22:00:00                                         NaN
# 2019-05-31 23:00:00                                         NaN
# 2019-06-01 00:00:00                                         NaN
# 2019-06-01 01:00:00                                         NaN
# 2019-06-01 02:00:00                                         NaN
#
#                      ActualConsumption FR Nuclear  ActualConsumption FR Solar  \
# date
# 2019-04-30 02:00:00                           NaN                         NaN
# 2019-04-30 03:00:00                           NaN                         NaN
# 2019-04-30 04:00:00                           NaN                         NaN
# 2019-04-30 05:00:00                           NaN                         NaN
# 2019-04-30 06:00:00                           NaN                         NaN
# ...                                           ...                         ...
# 2019-05-31 22:00:00                           NaN                         NaN
# 2019-05-31 23:00:00                           NaN                         NaN
# 2019-06-01 00:00:00                           NaN                         NaN
# 2019-06-01 01:00:00                           NaN                         NaN
# 2019-06-01 02:00:00                           NaN                         NaN
#
#                      ActualConsumption FR Waste  \
# date
# 2019-04-30 02:00:00                         NaN
# 2019-04-30 03:00:00                         NaN
# 2019-04-30 04:00:00                         NaN
# 2019-04-30 05:00:00                         NaN
# 2019-04-30 06:00:00                         NaN
# ...                                         ...
# 2019-05-31 22:00:00                         NaN
# 2019-05-31 23:00:00                         NaN
# 2019-06-01 00:00:00                         NaN
# 2019-06-01 01:00:00                         NaN
# 2019-06-01 02:00:00                         NaN
#
#                      ActualConsumption FR Wind Onshore  \
# date
# 2019-04-30 02:00:00                                NaN
# 2019-04-30 03:00:00                                NaN
# 2019-04-30 04:00:00                                NaN
# 2019-04-30 05:00:00                                NaN
# 2019-04-30 06:00:00                                NaN
# ...                                                ...
# 2019-05-31 22:00:00                                NaN
# 2019-05-31 23:00:00                                NaN
# 2019-06-01 00:00:00                                NaN
# 2019-06-01 01:00:00                                NaN
# 2019-06-01 02:00:00                                NaN
#
#                      TotalScheduledCommercialExchanges_FR_DE  \
# date
# 2019-04-30 02:00:00                                  1309.05
# 2019-04-30 03:00:00                                  2517.80
# 2019-04-30 04:00:00                                  2462.40
# 2019-04-30 05:00:00                                  1492.50
# 2019-04-30 06:00:00                                  1843.10
# ...                                                      ...
# 2019-05-31 22:00:00                                   822.20
# 2019-05-31 23:00:00                                   -84.70
# 2019-06-01 00:00:00                                  1342.30
# 2019-06-01 01:00:00                                   402.10
# 2019-06-01 02:00:00                                  1207.80
#
#                      TotalScheduledCommercialExchanges_FR_BE  \
# date
# 2019-04-30 02:00:00                                   1521.2
# 2019-04-30 03:00:00                                   1583.9
# 2019-04-30 04:00:00                                   1829.3
# 2019-04-30 05:00:00                                   1904.7
# 2019-04-30 06:00:00                                   1558.9
# ...                                                      ...
# 2019-05-31 22:00:00                                    996.7
# 2019-05-31 23:00:00                                     72.5
# 2019-06-01 00:00:00                                    382.7
# 2019-06-01 01:00:00                                   1016.8
# 2019-06-01 02:00:00                                   1385.8
#
#                      TotalScheduledCommercialExchanges_FR_CH  \
# date
# 2019-04-30 02:00:00                                   1849.5
# 2019-04-30 03:00:00                                   2230.6
# 2019-04-30 04:00:00                                   2275.4
# 2019-04-30 05:00:00                                   2663.2
# 2019-04-30 06:00:00                                   1230.4
# ...                                                      ...
# 2019-05-31 22:00:00                                   1434.5
# 2019-05-31 23:00:00                                   2229.3
# 2019-06-01 00:00:00                                   1719.8
# 2019-06-01 01:00:00                                   2494.4
# 2019-06-01 02:00:00                                   2275.0
#
#                      TotalScheduledCommercialExchanges_FR_IT  \
# date
# 2019-04-30 02:00:00                                   1494.0
# 2019-04-30 03:00:00                                   1494.0
# 2019-04-30 04:00:00                                   1494.0
# 2019-04-30 05:00:00                                   1120.0
# 2019-04-30 06:00:00                                   1120.0
# ...                                                      ...
# 2019-05-31 22:00:00                                   2509.0
# 2019-05-31 23:00:00                                   1770.0
# 2019-06-01 00:00:00                                   1120.0
# 2019-06-01 01:00:00                                   1120.0
# 2019-06-01 02:00:00                                   1120.0
#
#                      TotalScheduledCommercialExchanges_FR_ES
# date
# 2019-04-30 02:00:00                                   1500.0
# 2019-04-30 03:00:00                                   1500.0
# 2019-04-30 04:00:00                                   1500.0
# 2019-04-30 05:00:00                                   1500.0
# 2019-04-30 06:00:00                                   1471.2
# ...                                                      ...
# 2019-05-31 22:00:00                                   1700.0
# 2019-05-31 23:00:00                                   1700.0
# 2019-06-01 00:00:00                                   1300.0
# 2019-06-01 01:00:00                                   1300.0
# 2019-06-01 02:00:00                                   1300.0
#
# [769 rows x 34 columns]

# %%
# keeping only the data for the selected input date

df_data = df_merge.loc[(df_merge.index.month==month)&(df_merge.index.year==year)]

# %%
# we have the final dataset 

df_data
# Out:
#                      DayAheadPrices_FR  DayAheadPrices_DE  DayAheadPrices_BE  \
# date
# 2019-05-01 00:00:00              38.00              38.00              38.00
# 2019-05-01 01:00:00              35.20              35.20              35.20
# 2019-05-01 02:00:00              32.64              32.64              32.64
# 2019-05-01 03:00:00              31.16              31.16              31.16
# 2019-05-01 04:00:00              26.51              29.56              26.51
# ...                                ...                ...                ...
# 2019-05-01 01:00:00                                  1857.0
# 2019-05-01 02:00:00                                  1665.0
# 2019-05-01 03:00:00                                  1506.0
# 2019-05-01 04:00:00                                  1353.0
# ...                                                     ...
# 2019-05-31 19:00:00                                   594.0
# 2019-05-31 20:00:00                                   604.0
# 2019-05-31 21:00:00                                   649.0
# 2019-05-31 22:00:00                                   715.0
# 2019-05-31 23:00:00                                   774.0
#
#                      ActualConsumption FR Biomass  \
# date
# 2019-05-01 00:00:00                           NaN
# 2019-05-01 01:00:00                           NaN
# 2019-05-01 02:00:00                           NaN
# 2019-05-01 03:00:00                           NaN
# 2019-05-01 04:00:00                           NaN
# ...                                           ...
# 2019-05-31 19:00:00                           NaN
# 2019-05-31 20:00:00                           NaN
# 2019-05-31 21:00:00                           NaN
# 2019-05-31 22:00:00                           NaN
# 2019-05-31 23:00:00                           NaN
#
#                      ActualConsumption FR Fossil Gas  \
# date
# 2019-05-01 00:00:00                              NaN
# 2019-05-01 01:00:00                              NaN
# 2019-05-01 02:00:00                              NaN
# 2019-05-01 03:00:00                              NaN
# 2019-05-01 04:00:00                              NaN
# ...                                              ...
# 2019-05-31 19:00:00                              NaN
# 2019-05-31 20:00:00                              NaN
# 2019-05-31 21:00:00                              NaN
# 2019-05-31 22:00:00                              NaN
# 2019-05-31 23:00:00                              NaN
#
#                      ActualConsumption FR Fossil Hard coal  \
# date
# 2019-05-01 00:00:00                                    NaN
# 2019-05-01 01:00:00                                    NaN
# 2019-05-01 02:00:00                                    NaN
# 2019-05-01 03:00:00                                    NaN
# 2019-05-01 04:00:00                                    NaN
# ...                                                    ...
# 2019-05-31 19:00:00                                    NaN
# 2019-05-31 20:00:00                                    NaN
# 2019-05-31 21:00:00                                    NaN
# 2019-05-31 22:00:00                                    NaN
# 2019-05-31 23:00:00                                    NaN
#
#                      ActualConsumption FR Fossil Oil  \
# date
# 2019-05-01 00:00:00                              NaN
# 2019-05-01 01:00:00                              NaN
# 2019-05-01 02:00:00                              NaN
# 2019-05-01 03:00:00                              NaN
# 2019-05-01 04:00:00                              NaN
# ...                                              ...
# 2019-05-31 19:00:00                              NaN
# 2019-05-31 20:00:00                              NaN
# 2019-05-31 21:00:00                              NaN
# 2019-05-31 22:00:00                              NaN
# 2019-05-31 23:00:00                              NaN
#
#                      ActualConsumption FR Hydro Pumped Storage  \
# date
# 2019-05-01 00:00:00                                        NaN
# 2019-05-01 01:00:00                                      203.0
# 2019-05-01 02:00:00                                     1216.0
# 2019-05-01 03:00:00                                     2002.0
# 2019-05-01 04:00:00                                     2170.0
# ...                                                        ...
# 2019-05-31 19:00:00                                        NaN
# 2019-05-31 20:00:00                                        NaN
# 2019-05-31 21:00:00                                        NaN
# 2019-05-31 22:00:00                                        NaN
# 2019-05-31 23:00:00                                        NaN
#
#                      ActualConsumption FR Hydro Run-of-river and poundage  \
# date
# 2019-05-01 00:00:00                                                   NaN
# 2019-05-01 01:00:00                                                   NaN
# 2019-05-01 02:00:00                                                   NaN
# 2019-05-01 03:00:00                                                   NaN
# 2019-05-01 04:00:00                                                   NaN
# ...                                                                   ...
# 2019-05-31 19:00:00                                                   NaN
# 2019-05-31 20:00:00                                                   NaN
# 2019-05-31 21:00:00                                                   NaN
# 2019-05-31 22:00:00                                                   NaN
# 2019-05-31 23:00:00                                                   NaN
#
#                      ActualConsumption FR Hydro Water Reservoir  \
# date
# 2019-05-01 00:00:00                                         NaN
# 2019-05-01 01:00:00                                         NaN
# 2019-05-01 02:00:00                                         NaN
# 2019-05-01 03:00:00                                         NaN
# 2019-05-01 04:00:00                                         NaN
# ...                                                         ...
# 2019-05-31 19:00:00                                         NaN
# 2019-05-31 20:00:00                                         NaN
# 2019-05-31 21:00:00                                         NaN
# 2019-05-31 22:00:00                                         NaN
# 2019-05-31 23:00:00                                         NaN
#
#                      ActualConsumption FR Nuclear  ActualConsumption FR Solar  \
# date
# 2019-05-01 00:00:00                           NaN                         NaN
# 2019-05-01 01:00:00                           NaN                         NaN
# 2019-05-01 02:00:00                           NaN                         NaN
# 2019-05-01 03:00:00                           NaN                         NaN
# 2019-05-01 04:00:00                           NaN                         NaN
# ...                                           ...                         ...
# 2019-05-31 19:00:00                           NaN                         NaN
# 2019-05-31 20:00:00                           NaN                         NaN
# 2019-05-31 21:00:00                           NaN                         NaN
# 2019-05-31 22:00:00                           NaN                         NaN
# 2019-05-31 23:00:00                           NaN                         NaN
#
#                      ActualConsumption FR Waste  \
# date
# 2019-05-01 00:00:00                         NaN
# 2019-05-01 01:00:00                         NaN
# 2019-05-01 02:00:00                         NaN
# 2019-05-01 03:00:00                         NaN
# 2019-05-01 04:00:00                         NaN
# ...                                         ...
# 2019-05-31 19:00:00                         NaN
# 2019-05-31 20:00:00                         NaN
# 2019-05-31 21:00:00                         NaN
# 2019-05-31 22:00:00                         NaN
# 2019-05-31 23:00:00                         NaN
#
#                      ActualConsumption FR Wind Onshore  \
# date
# 2019-05-01 00:00:00                                NaN
# 2019-05-01 01:00:00                                NaN
# 2019-05-01 02:00:00                                NaN
# 2019-05-01 03:00:00                                NaN
# 2019-05-01 04:00:00                                NaN
# ...                                                ...
# 2019-05-31 19:00:00                                NaN
# 2019-05-31 20:00:00                                NaN
# 2019-05-31 21:00:00                                NaN
# 2019-05-31 22:00:00                                NaN
# 2019-05-31 23:00:00                                NaN
#
#                      TotalScheduledCommercialExchanges_FR_DE  \
# date
# 2019-05-01 00:00:00                                    56.25
# 2019-05-01 01:00:00                                   401.80
# 2019-05-01 02:00:00                                   273.30
# 2019-05-01 03:00:00                                  1051.10
# 2019-05-01 04:00:00                                  1258.35
# ...                                                      ...
# 2019-05-31 19:00:00                                  2572.80
# 2019-05-31 20:00:00                                  2400.00
# 2019-05-31 21:00:00                                  1799.70
# 2019-05-31 22:00:00                                   822.20
# 2019-05-31 23:00:00                                   -84.70
#
#                      TotalScheduledCommercialExchanges_FR_BE  \
# date
# 2019-05-01 00:00:00                                   1597.9
# 2019-05-01 01:00:00                                   1989.4
# 2019-05-01 02:00:00                                   2180.0
# 2019-05-01 03:00:00                                   2531.5
# 2019-05-01 04:00:00                                   2924.1
# ...                                                      ...
# 2019-05-31 19:00:00                                    769.0
# 2019-05-31 20:00:00                                    733.0
# 2019-05-31 21:00:00                                    765.0
# 2019-05-31 22:00:00                                    996.7
# 2019-05-31 23:00:00                                     72.5
#
#                      TotalScheduledCommercialExchanges_FR_CH  \
# date
# 2019-05-01 00:00:00                                   1448.2
# 2019-05-01 01:00:00                                   1313.6
# 2019-05-01 02:00:00                                   1497.8
# 2019-05-01 03:00:00                                   1828.6
# 2019-05-01 04:00:00                                   2022.6
# ...                                                      ...
# 2019-05-31 19:00:00                                   2600.0
# 2019-05-31 20:00:00                                   2600.0
# 2019-05-31 21:00:00                                   2600.0
# 2019-05-31 22:00:00                                   1434.5
# 2019-05-31 23:00:00                                   2229.3
#
#                      TotalScheduledCommercialExchanges_FR_IT  \
# date
# 2019-05-01 00:00:00                                   1296.0
# 2019-05-01 01:00:00                                    747.0
# 2019-05-01 02:00:00                                    747.0
# 2019-05-01 03:00:00                                    747.0
# 2019-05-01 04:00:00                                    747.0
# ...                                                      ...
# 2019-05-31 19:00:00                                   2805.0
# 2019-05-31 20:00:00                                   2995.0
# 2019-05-31 21:00:00                                   2995.0
# 2019-05-31 22:00:00                                   2509.0
# 2019-05-31 23:00:00                                   1770.0
#
#                      TotalScheduledCommercialExchanges_FR_ES
# date
# 2019-05-01 00:00:00                                   2000.0
# 2019-05-01 01:00:00                                   2000.0
# 2019-05-01 02:00:00                                   2000.0
# 2019-05-01 03:00:00                                   2000.0
# 2019-05-01 04:00:00                                   2000.0
# ...                                                      ...
# 2019-05-31 19:00:00                                   1700.0
# 2019-05-31 20:00:00                                   1700.0
# 2019-05-31 21:00:00                                   1700.0
# 2019-05-31 22:00:00                                   1700.0
# 2019-05-31 23:00:00                                   1700.0
#
# [744 rows x 34 columns]

# %%
def create_plot(
    title = None,
    df = None,
    country_code = country,
    list_interco = None,
    list_colors = None,
    list_flows = None,
    list_DA_prices = None,
    list_gen_types = None,
    list_gen_types_labels = None,
    ):
    
    from plotly.subplots import make_subplots
    
    #-----------------------------------------------------------------------------
    fig = plotly.subplots.make_subplots(
        rows=3, cols=1, 
        subplot_titles = (
            'Spot Price',
            'Generation and Demand',
            'Cross Border Flows DA: (+): Exports, (-): Imports',
        ),
        shared_xaxes=True,
        vertical_spacing=0.05,
        #specs=[[{"secondary_y": True}], [{"secondary_y": False}], [{"secondary_y": False}]]
    )
    #-----------------------------------------------------------------------------
    # Spot price
    
    for col, color in zip(list_DA_prices, list_colors):
        trace = go.Scatter(
            x = df.index, 
            y = df[col], 
            name = col,
            line_color = color,
            )
        fig.append_trace(trace, 1, 1)
    
    
    #-----------------------------------------------------------------------------
    
    # Generation
    
    for col_gen_type, label in zip(list_gen_types, list_gen_types_labels):
        try:
            trace = go.Bar(
                x = df.index, 
                y = df[col_gen_type], 
                name = label,
                    #marker_color = color,
                    #legendgroup = country,
                    #showlegend=False,
                )
            fig.append_trace(trace, 2, 1)
        except KeyError:
            pass
            
    # Demand
    
    trace = go.Scatter(
        x = df.index, 
        y = df['ActualTotalLoad'+'_'+country_code], 
        name = 'Demand',
        #visible = 'legendonly',
        line_color = 'black',
    )
    fig.add_trace(trace, 2, 1, 
                  #secondary_y=True
                 )
    fig.update_layout(yaxis_title='MW')

    #-----------------------------------------------------------------------------
    # flows
    
    for flow, country, color in zip(list_flows, list_interco, list_colors[1:]):
        trace = go.Bar(
            x = df.index, 
            y = df[flow], 
            name = 'Flows '+ country,
            marker_color = color,
            legendgroup = country,
            )
        fig.append_trace(trace, 3, 1)
    fig.update_layout(yaxis_title='MW')
  
    #-----------------------------------------------------------------------------
    fig.update_layout(
        title_text = title,
        barmode='relative',
        bargap=0,
        #bargroupgap=0,
       xaxis3_rangeslider_visible=True, xaxis3_rangeslider_thickness=0.05 ,
        
        xaxis=dict(
            autorange=True,
            #rangeslider=dict(
                #autorange=True,
            #),
            #type="date",
            #title='Date and Time'
        ),
        
        # xaxis2_rangeslider_visible=True,
        
        yaxis1 = dict(
            anchor = "x",
            autorange = True,
            title_text = "€/MWh"
            
        ),
        
        yaxis2 = dict(
            anchor = "x",
            autorange = True,
            title_text = "MWh/h",
        ),
        
        yaxis3 = dict(
            anchor = "x",
            autorange = True,
            title_text = "MWh/h",
        ),
    )
    
    return fig

# %%
gen_tech = [
        'Nuclear',
        'Biomass',
        'Hydro R-o-R',
        'Hard coal',
        'Lignite',
        'CCGT',
        'Pumped Storage',
        'Hydro Reservoir',
        'Wind Offshore',
        'Wind Onshore',
        'Solar',
                ]

fig = create_plot(
    
    title = country + ' Electricity Generation - ' + ref_date.strftime("%B") + '/' + str(year),
    
    df = df_data,
    
    country_code = country,
    
    list_interco = interco,
    
    list_colors = ['deepskyblue', 'red', 'orange', 'green','silver','maroon'],
    
    list_flows = list(df_flows.columns.values),
    
    list_DA_prices = list(df_DA_price.columns.values),
    

     list_gen_types = [

        'ActualGenerationOutput' + ' ' + country + ' ' + 'Nuclear',
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Biomass',
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Hydro Run-of-river and poundage',

        'ActualGenerationOutput' + ' ' + country + ' ' + 'Fossil Hard coal',
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Fossil Brown coal/Lignite',
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Fossil Gas',
         
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Hydro Pumped Storage',
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Hydro Water Reservoir',
         
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Wind Offshore',
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Wind Onshore',
        'ActualGenerationOutput' + ' ' + country + ' ' + 'Solar',

                        ],
    
    list_gen_types_labels = gen_tech

)
outdir = 'plots/'
outfile = country + '_' + 'Stack' + '_' + ref_date.strftime("%B") + '_' + str(ref_date.year) + '.html'

plotly.offline.plot(fig, filename = os.path.join(outdir, outfile))
# Out:
# 'plots/FR_Stack_May_2019.html'
